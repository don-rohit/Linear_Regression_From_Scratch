# %%
# Importing Necessary Libraries
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Size of plot width=20, height=10
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
# Reading Data
data = pd.read_csv('headbrain.csv')
print(data.shape)
data.head()
# Out:
# (237, 4)
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
# Collecting X and Y
# using Head Size to Predict Brain Weight
x = data['Head Size(cm^3)']/100
y = data['Brain Weight(grams)']/100

# %%
# Plotting Dataset
plt.scatter(x, y, c='#ef5423', label='Scatter Plot')
plt.xlabel('Head Size in cm3')
plt.ylabel('Brain Weight in grams')
plt.legend()
plt.show()

# %%
# Linear Regression Parameters
learning_rate = 0.0001
iters = 100000  
m = len(x) # No of Data points

theta = [0.0,0.0]

# %%
for epoch in range(iters):
    loss = 0
    j0 = 0
    j1 = 0
    for i in range(m):
        # Compute Hypothesis
        h = theta[0] + theta[1]*x[i]
        # Compute Loss
        loss = h-y[i]
        
        j0 += h-y[i]
        j1 += (h-y[i])* x[0]
    
    # Gradient Descent
    theta[0] = theta[0] - learning_rate * (j0/m)
    theta[1] = theta[1] - learning_rate * (j1/m)
    
    
    if epoch%1000 == 0:
        print(epoch,theta[0]*100,theta[1]*100)
# Out:
# 0 0.7819266450331797 35.280530223897074
# 1000 0.7819266450331797 35.280530223897074
# 2000 0.7819266450331797 35.280530223897074
# 3000 0.7819266450331797 35.280530223897074
# 4000 0.7819266450331797 35.280530223897074
# 5000 0.7819266450331797 35.280530223897074
# 6000 0.7819266450331797 35.280530223897074
# 7000 0.7819266450331797 35.280530223897074
# 8000 0.7819266450331797 35.280530223897074
# 9000 0.7819266450331797 35.280530223897074
# 10000 0.7819266450331797 35.280530223897074
# 11000 0.7819266450331797 35.280530223897074
# 12000 0.7819266450331797 35.280530223897074
# 13000 0.7819266450331797 35.280530223897074
# 14000 0.7819266450331797 35.280530223897074
# 15000 0.7819266450331797 35.280530223897074
# 16000 0.7819266450331797 35.280530223897074
# 17000 0.7819266450331797 35.280530223897074
# 18000 0.7819266450331797 35.280530223897074
# 19000 0.7819266450331797 35.280530223897074
# 20000 0.7819266450331797 35.280530223897074
# 21000 0.7819266450331797 35.280530223897074
# 22000 0.7819266450331797 35.280530223897074
# 23000 0.7819266450331797 35.280530223897074
# 24000 0.7819266450331797 35.280530223897074
# 25000 0.7819266450331797 35.280530223897074
# 26000 0.7819266450331797 35.280530223897074
# 27000 0.7819266450331797 35.280530223897074
# 28000 0.7819266450331797 35.280530223897074
# 29000 0.7819266450331797 35.280530223897074
# 30000 0.7819266450331797 35.280530223897074
# 31000 0.7819266450331797 35.280530223897074
# 32000 0.7819266450331797 35.280530223897074
# 33000 0.7819266450331797 35.280530223897074
# 34000 0.7819266450331797 35.280530223897074
# 35000 0.7819266450331797 35.280530223897074
# 36000 0.7819266450331797 35.280530223897074
# 37000 0.7819266450331797 35.280530223897074
# 38000 0.7819266450331797 35.280530223897074
# 39000 0.7819266450331797 35.280530223897074
# 40000 0.7819266450331797 35.280530223897074
# 41000 0.7819266450331797 35.280530223897074
# 42000 0.7819266450331797 35.280530223897074
# 43000 0.7819266450331797 35.280530223897074
# 44000 0.7819266450331797 35.280530223897074
# 45000 0.7819266450331797 35.280530223897074
# 46000 0.7819266450331797 35.280530223897074
# 47000 0.7819266450331797 35.280530223897074
# 48000 0.7819266450331797 35.280530223897074
# 49000 0.7819266450331797 35.280530223897074
# 50000 0.7819266450331797 35.280530223897074
# 51000 0.7819266450331797 35.280530223897074
# 52000 0.7819266450331797 35.280530223897074
# 53000 0.7819266450331797 35.280530223897074
# 54000 0.7819266450331797 35.280530223897074
# 55000 0.7819266450331797 35.280530223897074
# 56000 0.7819266450331797 35.280530223897074
# 57000 0.7819266450331797 35.280530223897074
# 58000 0.7819266450331797 35.280530223897074
# 59000 0.7819266450331797 35.280530223897074
# 60000 0.7819266450331797 35.280530223897074
# 61000 0.7819266450331797 35.280530223897074
# 62000 0.7819266450331797 35.280530223897074
# 63000 0.7819266450331797 35.280530223897074
# 64000 0.7819266450331797 35.280530223897074
# 65000 0.7819266450331797 35.280530223897074
# 66000 0.7819266450331797 35.280530223897074
# 67000 0.7819266450331797 35.280530223897074
# 68000 0.7819266450331797 35.280530223897074
# 69000 0.7819266450331797 35.280530223897074
# 70000 0.7819266450331797 35.280530223897074
# 71000 0.7819266450331797 35.280530223897074
# 72000 0.7819266450331797 35.280530223897074
# 73000 0.7819266450331797 35.280530223897074
# 74000 0.7819266450331797 35.280530223897074
# 75000 0.7819266450331797 35.280530223897074
# 76000 0.7819266450331797 35.280530223897074
# 77000 0.7819266450331797 35.280530223897074
# 78000 0.7819266450331797 35.280530223897074
# 79000 0.7819266450331797 35.280530223897074
# 80000 0.7819266450331797 35.280530223897074
# 81000 0.7819266450331797 35.280530223897074
# 82000 0.7819266450331797 35.280530223897074
# 83000 0.7819266450331797 35.280530223897074
# 84000 0.7819266450331797 35.280530223897074
# 85000 0.7819266450331797 35.280530223897074
# 86000 0.7819266450331797 35.280530223897074
# 87000 0.7819266450331797 35.280530223897074
# 88000 0.7819266450331797 35.280530223897074
# 89000 0.7819266450331797 35.280530223897074
# 90000 0.7819266450331797 35.280530223897074
# 91000 0.7819266450331797 35.280530223897074
# 92000 0.7819266450331797 35.280530223897074
# 93000 0.7819266450331797 35.280530223897074
# 94000 0.7819266450331797 35.280530223897074
# 95000 0.7819266450331797 35.280530223897074
# 96000 0.7819266450331797 35.280530223897074
# 97000 0.7819266450331797 35.280530223897074
# 98000 0.7819266450331797 35.280530223897074
# 99000 0.7819266450331797 35.280530223897074

# %%
0.26342933948939945 325.57342104944223

# %%
print(x[1],y[1])
print(theta[0] + theta[1]*x[1])
# Out:
# 37.38 12.97
# 13.19568146414306

# %%
y_pred = []
for i in range(m):
    y_pred.append(theta[0] + theta[1]*x[i])

# %%
max_x = np.max(math) + 100
min_x = np.min(math) - 100

max_y = np.max(read) + 100
min_y = np.min(read) - 100

max_yp = np.max(y_pred) + 100
min_yp = np.min(y_pred) - 100

# Calculating line values x and y
x = np.linspace(min_x, max_x, 1000)
y = np.linspace(min_y, max_y, 1000)
yp = np.linspace(min_yp, max_yp, 1000)

# Ploting the scores as scatter plot

fig = plt.figure()
ax = Axes3D(fig)
ax.plot(x, y, yp, color='#58b970', label='Regression Line')
ax.scatter(math, read, write, color='#ef1234',label='Data Point')
ax.set_xlabel('Math')
ax.set_ylabel('Reading')
ax.set_zlabel("Writing")
plt.legend()
plt.show()
